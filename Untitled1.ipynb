# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d = pd.read_csv("/Users/rlx/Downloads/6119.csv")

# %%
d = d.set_index("AADFYear")
d.columns
# Out:
# Index([u'CP', u'Estimation_method', u'Estimation_method_detailed', u'Region',
#        u'LocalAuthority', u'Road', u'RoadCategory', u'Easting', u'Northing',
#        u'StartJunction', u'EndJunction', u'LinkLength_km', u'LinkLength_miles',
#        u'PedalCycles', u'Motorcycles', u'CarsTaxis', u'BusesCoaches',
#        u'LightGoodsVehicles', u'V2AxleRigidHGV', u'V3AxleRigidHGV',
#        u'V4or5AxleRigidHGV', u'V3or4AxleArticHGV', u'V5AxleArticHGV',
#        u'V6orMoreAxleArticHGV', u'AllHGVs', u'AllMotorVehicles'],
#       dtype='object')

# %%
d[[u'PedalCycles', u'Motorcycles', u'CarsTaxis',u'BusesCoaches']].plot()

# %%
d = pd.read_csv("/Users/rlx/Downloads/8448.csv")
d = d.set_index("AADFYear")
d[[u'PedalCycles', u'Motorcycles', u'CarsTaxis',u'BusesCoaches']].plot()

# %%
d.iloc[0]
# Out:
# CP                                                                         8448
# Estimation_method                                                     Estimated
# Estimation_method_detailed    Estimated using previous year's AADF on this link
# Region                                                                   London
# LocalAuthority                                                      Westminster
# Road                                                                         A4
# RoadCategory                                                                 PU
# Easting                                                                  529610
# Northing                                                                 180500
# StartJunction                                                         Pall Mall
# EndJunction                                                   Piccadilly Circus
# LinkLength_km                                                               0.3
# ...
